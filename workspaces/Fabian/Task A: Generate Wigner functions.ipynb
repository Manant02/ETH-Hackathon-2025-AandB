# %%
import dynamiqs as dq
import jax.numpy as jnp
import jax
from dynamiqs import *
import matplotlib.pyplot as plt

import imageio

# %%
#parameters
pi=jnp.pi
N=30 #Hilbert space dimension
n=2 #number Fock state
alpha=2 #coherent state amplitude
g2=1.0
k_b=10
e_d=-4

T      = 4.0      # total time
n_steps = 80      # number frame
tlist  = jnp.linspace(0, T, n_steps)

# %%
#operators and states
a=destroy(N)
I  = eye(N)
a_sys  = tensor(a,  I)
adag_sys = a_sys.dag()
b_sys  = tensor(I,  a)
bdag_sys = b_sys.dag()
H=g2.conjugate()*adag_sys@adag_sys@b_sys+g2*a_sys@a_sys@bdag_sys+e_d.conjugate()*b_sys+e_d*bdag_sys

c_ops = [jnp.sqrt(k_b) * b_sys]

vacuum_state=tensor(basis(N,0), basis(N,0))

fock_state=fock(N, n)
coherent_state=coherent(N, alpha)
cat_state=1/jnp.sqrt(2)*(coherent(N,alpha)+coherent(N,-alpha))
cat_state_3=1/jnp.sqrt(3)*(coherent(N,alpha)+coherent(N,jnp.exp(1j*2*pi/3)*alpha)+coherent(N,jnp.exp(-1j*2*pi/3)*alpha))

# %%
#Wigner functions
"""gridspace=jnp.linspace(-5,5, 100)
W_fock = wigner(fock_state, xvec=gridspace, yvec=gridspace)
W_coherent = wigner(coherent_state, xvec=gridspace, yvec=gridspace)"""
W_coherent=wigner(coherent_state, 5,5)
W_fock2 = wigner(fock_state,5,5)

# %%
xvec, yvec, W_fock=W_fock2

# %%
plt.contourf(xvec, yvec,W_fock, levels=100,cmap="seismic", vmax=1, vmin=-1)
plt.xlabel("x")
plt.ylabel("p")
plt.colorbar()

# %%
xvec,yvec, W_coherent=W_coherent
plt.contourf(xvec, yvec,W_coherent, levels=100,cmap="seismic", vmax=2/pi, vmin=-2/pi)
plt.xlabel("x")
plt.ylabel("p")
plt.colorbar()

# %%
xvec,yvec, W_coherent=wigner(cat_state, 5,5)
plt.contourf(xvec, yvec,W_coherent, levels=100,cmap="seismic", vmax=2/pi, vmin=-2/pi)
plt.xlabel("x")
plt.ylabel("p")
plt.colorbar()

# %%
xvec,yvec, W_coherent=wigner(cat_state_3, 5,5)
plt.contourf(xvec, yvec,W_coherent, levels=100,cmap="seismic", vmax=2/pi, vmin=-2/pi)
plt.xlabel("x")
plt.ylabel("p")
plt.colorbar()

# %%
result = mesolve(H, c_ops, vacuum_state, tlist)

filenames = []
for idx, rho_ab in enumerate(result.states):
    
    rho_a = rho_ab.ptrace(0)
    
    W = wigner(rho_a, xvec, yvec)

    # plot
    fig, ax = plt.subplots(figsize=(4,4))
    c = ax.contourf(xvec, yvec, W, levels=100)
    ax.set_title(f"t = {tlist[idx]:.2f}")
    ax.set_xlabel("Re α")
    ax.set_ylabel("Im α")

    # save frame
    fname = f"frame_{idx:03d}.png"
    plt.savefig(fname, dpi=100)
    plt.close(fig)
    filenames.append(fname)

# ─── BUILD GIF ────────────────────────────────────────────────────────────────
with imageio.get_writer('wigner_evolution.gif', mode='I', fps=10) as writer:
    for fname in filenames:
        image = imageio.imread(fname)
        writer.append_data(image)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 result = mesolve(H, vacuum_state, tlist, c_ops)
#       3 filenames = []
#       4 for idx, rho_ab in enumerate(result.states):
#
# File ~/miniconda3/envs/qutip/lib/python3.12/site-packages/dynamiqs/integrators/apis/mesolve.py:219, in mesolve(H, jump_ops, rho0, tsave, exp_ops, method, gradient, options)
#     217 # === convert arguments
#     218 H = astimeqarray(H)
# --> 219 Ls = [astimeqarray(L) for L in jump_ops]
#     220 rho0 = asqarray(rho0)
#     221 tsave = jnp.asarray(tsave)
#
# File ~/miniconda3/envs/qutip/lib/python3.12/site-packages/dynamiqs/qarrays/qarray.py:537, in QArray.__iter__(self)
#     535 def __iter__(self):
#     536     for i in range(self.shape[0]):
# --> 537         yield self[i]
#
# File ~/miniconda3/envs/qutip/lib/python3.12/site-packages/dynamiqs/qarrays/dense_qarray.py:231, in DenseQArray.__getitem__(self, key)
#     229 def __getitem__(self, key: int | slice) -> QArray:
#     230     data = self.data[key]
# --> 231     return self._replace(data=data)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/qutip/lib/python3.12/site-packages/dynamiqs/qarrays/dense_qarray.py:38, in DenseQArray._replace(self, dims, vectorized, data)
#      36 if data is None:
#      37     data = self.data
# ---> 38 return super()._replace(dims=dims, vectorized=vectorized, data=data)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/qutip/lib/python3.12/site-packages/dynamiqs/qarrays/qarray.py:249, in QArray._replace(self, dims, vectorized, **kwargs)
#     247 if vectorized is None:
#     248     vectorized = self.vectorized
# --> 249 return type(self)(dims=dims, vectorized=vectorized, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/qutip/lib/python3.12/site-packages/dynamiqs/qarrays/qarray.py:264, in QArray.__check_init__(self)
#     260 # === ensure dims is compatible with the shape
#     261 # for vectorized superoperators, we allow that the shape is the square
#     262 # of the product of all dims
#     263 allowed_shapes = (prod(self.dims), prod(self.dims) ** 2)
# --> 264 if not (self.shape[-1] in allowed_shapes or self.shape[-2] in allowed_shapes):
#     265     raise ValueError(
#     266         'Argument `dims` must be compatible with the shape of the qarray, but '
#     267         f'got dims {self.dims} and shape {self.shape}.'
#     268     )
#
# IndexError: tuple index out of range
